# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %% [markdown]
# ### FBI Most Wanted
#
# This API could be useful for a project evaluating personal factors in most wanted profiles, like their professions or age, to potentially correlate factors into these actions warranting them to be on this list. The FBI officially announced the list to increase law enforcement's ability to capture dangerous fugitives.

# %%
import pandas as pd 
import requests
from pandas import json_normalize

# %%
res = requests.get('https://api.fbi.gov/wanted/v1/list')
type(res)
# Out:
# requests.models.Response

# %%
data = res.json()

# %%
data.keys()
# Out:
# dict_keys(['total', 'items', 'page'])

# %%
most_wanted = json_normalize(data['items'])
most_wanted.head()
# Out:
#    reward_max                                            caution  \
# 0           0  <p>Christopher John Worrell is wanted for viol...
# 1           0  <p>Robert William Fisher is wanted for alleged...
# 2           0                                               None
# 3           0                                               None
# 4           0                                               None
#
#                                              details additional_information  \
# 0                                               None                   None
# 1                                               None                   None
# 2  <p>On May 22, 1989, Dawn Marie Mozino was last...                   None
# 3  <p>On April 3, 2020, the partially skeletonize...                   None
# 4  <p>On Friday, September 2, 1977, (Labor Day we...                   None
#
#               aliases languages  age_max  \
# 0                None      None      NaN
# 1  [Robert W. Fisher]      None      NaN
# 2                None      None     24.0
# 3                None      None     50.0
# 4                None      None     17.0
#
#                                          occupations  \
# 0                                               None
# 1  [Surgical Catheter Technician, Respiratory The...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                files race_raw  ...   build  \
# 0  [{'url': 'https://www.fbi.gov/wanted/additiona...    White  ...    None
# 1  [{'url': 'https://www.fbi.gov/wanted/murders/r...    White  ...  Medium
# 2  [{'url': 'https://www.fbi.gov/wanted/vicap/mis...    White  ...    None
# 3  [{'url': 'https://www.fbi.gov/wanted/vicap/uni...    White  ...    None
# 4  [{'url': 'https://www.fbi.gov/wanted/vicap/mis...    White  ...    None
#
#    poster_classification  reward_text person_classification status  \
# 0                default         None                  Main     na
# 1                default         None                  Main     na
# 2                default         None                  Main     na
# 3                default         None                  Main     na
# 4                default         None                Victim     na
#
#                                      warning_message      place_of_birth  \
# 0                                               None            New York
# 1  SHOULD BE CONSIDERED ARMED AND EXTREMELY DANGE...  Brooklyn, New York
# 2                                               None                None
# 3                                               None                None
# 4                                               None                None
#
#   nationality legat_names                                                @id
# 0    American        None  https://api.fbi.gov/@wanted-person/777ceebf76c...
# 1    American        None  https://api.fbi.gov/@wanted-person/83a7764745a...
# 2        None        None  https://api.fbi.gov/@wanted-person/6821fa45714...
# 3        None        None  https://api.fbi.gov/@wanted-person/9dc24203f49...
# 4        None        None  https://api.fbi.gov/@wanted-person/70eaa8aa5d4...
#
# [5 rows x 54 columns]

# %% [markdown]
# Since this is a single page of profiles, we could use a `for` loop to iterate over the number of pages to get even more information of these individuals.

# %% [markdown]
# ### Legend of Zelda- Hyrule Compendium
#
# This compendium covers all items that Link (the player) can interact with in the game, from all sorts of creatures and monsters to treasures. This can be used for a guide to players who are having a hard time completing the game; looking into the structure and seeing potential monster item drops or treasure locations, this information can be used to create a list of daily outcome-focused tasks to help players reach their goals in levelling up their skills and toolkit for the story.

# %%
res=requests.get('https://botw-compendium.herokuapp.com/api/v3/compendium/all')
type(res)
# Out:
# requests.models.Response

# %%
data = res.json()

# %%
data.keys()
# Out:
# dict_keys(['data'])

# %%
hyrule_compendium = json_normalize(data['data'])
hyrule_compendium
# Out:
#       category                     common_locations  \
# 0     treasure                     [Greater Hyrule]
# 1     treasure                     [Greater Hyrule]
# 2     treasure                     [Greater Hyrule]
# 3     treasure                     [Greater Hyrule]
# 4     monsters                      [Gerudo Desert]
# ..         ...                                  ...
# 384  creatures                      [Gerudo Desert]
# 385  creatures  [Hebra Mountains, Gerudo Highlands]
# 386  creatures         [Hyrule Field, Hyrule Ridge]
# 387  creatures                                 None
# 388  creatures     [Hyrule Field, Faron Grasslands]
#
#                                            description    dlc  \
# 0    This deposit contains a good deal of ore. Brea...  False
# 1    Fortunes untold (potentially) await the lucky ...  False
# 2    This deposit contains a good deal of precious ...  False
# 3    This deposit contains quite a bit of luminous ...  False
# 4    This massive monster swims beneath the desert'...  False
# ..                                                 ...    ...
# 384  This is Riju's own sand seal. It may look inte...  False
# 385  This white-feathered breed of pigeon lives in ...  False
# 386  These small creatures are known for their larg...  False
# 387  The Hyrulean royal family that perished 100 ye...  False
# 388  These can most often be found on plains. Their...  False
#
#                                                  drops   id  \
# 0    [ruby, diamond, amber, sapphire, topaz, opal, ...  387
# 1                                          [treasures]  386
# 2       [ruby, sapphire, diamond, amber, topaz, flint]  388
# 3                                    [luminous, flint]  389
# 4                          [molduga fin, molduga guts]  151
# ..                                                 ...  ...
# 384                                                 []    8
# 385                   [raw bird thigh, raw whole bird]   39
# 386                                            [acorn]    9
# 387                                               None    3
# 388                                                 []    1
#
#                                                  image                   name  \
# 0    https://botw-compendium.herokuapp.com/api/v3/c...            ore deposit
# 1    https://botw-compendium.herokuapp.com/api/v3/c...         treasure chest
# 2    https://botw-compendium.herokuapp.com/api/v3/c...       rare ore deposit
# 3    https://botw-compendium.herokuapp.com/api/v3/c...   luminous ore deposit
# 4    https://botw-compendium.herokuapp.com/api/v3/c...                molduga
# ..                                                 ...                    ...
# 384  https://botw-compendium.herokuapp.com/api/v3/c...               patricia
# 385  https://botw-compendium.herokuapp.com/api/v3/c...           white pigeon
# 386  https://botw-compendium.herokuapp.com/api/v3/c...  bushy-tailed squirrel
# 387  https://botw-compendium.herokuapp.com/api/v3/c...            white horse
# 388  https://botw-compendium.herokuapp.com/api/v3/c...                  horse
#
#     cooking_effect  hearts_recovered  properties.attack  properties.defense  \
# 0              NaN               NaN                NaN                 NaN
# 1              NaN               NaN                NaN                 NaN
# 2              NaN               NaN                NaN                 NaN
# 3              NaN               NaN                NaN                 NaN
# 4              NaN               NaN                NaN                 NaN
# ..             ...               ...                ...                 ...
# 384            NaN               NaN                NaN                 NaN
# 385            NaN               NaN                NaN                 NaN
# 386            NaN               NaN                NaN                 NaN
# 387            NaN               NaN                NaN                 NaN
# 388            NaN               NaN                NaN                 NaN
#
#     edible
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 384  False
# 385  False
# 386  False
# 387  False
# 388  False
#
# [389 rows x 13 columns]

# %% [markdown]
# ### Dog Facts
#
# This dataset brings joy, so it could be used for self-care/curiosity projects because it feels nice to read about dogs.

# %%
res=requests.get('http://dog-api.kinduff.com/api/facts?number=100')
type(res)
# Out:
# requests.models.Response

# %%
data=res.json()

# %%
dog_facts=pd.DataFrame(data['facts'])
dog_facts.columns=['facts']

# %%
dog_facts
# Out:
#                                                 facts
# 0   Most dogs are capable of understanding up to 2...
# 1   Dogs are capable of understanding up to 250 wo...
# 2   A one year old dog is as physically mature as ...
# 3       Three of the 12 dogs on the Titanic survived.
# 4   The dog was frequently depicted in Greek art, ...
# ..                                                ...
# 95  Service dogs are recognized in the U.S. as "ne...
# 96  Service dogs are trained to know when they are...
# 97  In Egypt, a person bitten by a rabid dog was e...
# 98  President Theodore Roosevelt's Bull Terrier Pe...
# 99  Within hours of the September 11, 2001, attack...
#
# [100 rows x 1 columns]
